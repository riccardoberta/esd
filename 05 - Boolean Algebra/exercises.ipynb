# %% [markdown]
# # Boolean Algebra Exercises

# %% [markdown]
# ## Exercise 1
#
# For each given truth table, write the Boolean equation in canonical **sum-of-products** form. Then simplify the expression to its minimal form using the theorems of Boolean algebra. Finally, implement the corresponding combinational circuit and verify its correctness by simulating it in DEEDS

# %% [markdown]
# ### (a)
#
# ![image.png](attachment:image-algebra-exe-01.png)

# %% [markdown]
# ### (b)
#
# ![image.png](attachment:image-algebra-exe-03.png)

# %% [markdown]
# ### (c)
#
# ![image.png](attachment:image-algebra-exe-05.png)

# %% [markdown]
# ### (d)
#
# ![image.png](attachment:image-algebra-exe-07.png)

# %% [markdown]
# ### (e)
#
# ![image.png](attachment:image-algebra-exe-09.png)

# %% [markdown]
# ## Exercise 2
#
# Complete the truth table and the timing diagram of the following digital circuits. Then derive the Boolean equation in canonical **sum-of-products** form and simplify it to its minimal expression using Boolean algebra theorems. Finally, implement the corresponding circuit in DEEDS and verify the correctness of your solution.

# %% [markdown]
# ### (a)
#
# ![image.png](attachment:image-algebra-exe-14.png)
#
# ![image.png](attachment:image-algebra-exe-11.png)

# %% [markdown]
# ### (b)
#
# ![image.png](attachment:image-algebra-exe-14b.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-15.png)

# %% [markdown]
# ### (c)
#
# ![image.png](attachment:image-algebra-exe-18.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-19.png)

# %% [markdown]
# ### (d)
#
# ![image.png](attachment:image-algebra-exe-22.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-23.png)

# %% [markdown]
# ### (e)
#
# ![image.png](attachment:image-algebra-exe-26.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-27.png)

# %% [markdown]
# ### (f)
#
# ![image.png](attachment:image-algebra-exe-30.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-31.png)

# %% [markdown]
# ### (g)
#
# ![image.png](attachment:image-algebra-exe-34.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-35.png)

# %% [markdown]
# ## Exercise 3
#
# Complete the truth table and the timing diagram of the following digital circuits. Then derive the Boolean equation in canonical **product-of-sums** form and simplify it to its minimal expression using Boolean algebra theorems. Finally, implement the corresponding circuit in DEEDS and verify the correctness of your solution.

# %% [markdown]
# ### (a)
#
# ![image.png](attachment:image-algebra-exe-38.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-39.png)

# %% [markdown]
# ### (b)
#
# ![image.png](attachment:image-algebra-exe-42.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-43.png)

# %% [markdown]
# ### (c)
#
# ![image.png](attachment:image-algebra-exe-46.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-47.png)

# %% [markdown]
# ### (d)
#
# ![image.png](attachment:image-algebra-exe-50.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-51.png)

# %% [markdown]
# ## Exercise 4
#
# Consider the following circuits. The first one is a **2-bit comparator**, which determines whether the value of A is equal to the value of B. The second one is a **1-bit adder**, which adds A, B, and the input carry, generating both the sum and the carry outputs. Complete the truth table and the timing diagram. Explain the operation of the two circuits in light of the truth table, and verify that they behave as expected. Then implement the corresponding circuits in DEEDS and verify the correctness of your solutions through simulation.

# %% [markdown]
# ### (a) 2-bit comparator
#
# ![image.png](attachment:image-algebra-exe-54.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-55.png)

# %% [markdown]
# ### (b) 1-bit adder
#
# ![image.png](attachment:image-algebra-exe-58.png)

# %% [markdown]
# ![image.png](attachment:image-algebra-exe-59.png)
